# %% [markdown]
# Getting Started | Data Prep | Data Exploration | **Preprocessing** | Model Tuning | Final Model

# %% [markdown]
# *For preprocessing, we will:*
# * Create a Preprocessor object to process data
# * Complete feature engineering and value imputation (if needed)
# * Encode categorical Variables

# %%
import pandas as pd
import numpy as np

# %%
# adding the modules directory to path
import sys
sys.path.insert(0, '../modules')

# reading in functions
from helpers import read_in_dataset, get_percent, filter_duplicates, get_data

# %% [markdown]
# ## Read in Data

# %%
train_X, train_y = get_data('train')

# %%
# Sanity check for lengths and opportunity numbers
assert len(train_X) == len(train_y)
assert set(train_X.index) == set(train_y.index)

# %% [markdown]
# ## Create Initial Preprocessor Object

# %%
class Preprocessor: 
    
    def __init__(self, cols_to_filter=None):
        self.cols_to_filter = cols_to_filter
        
    def fit(self, X_features, y_target=None):
        '''
        Learn information from training get to transform test set
        '''
        
        return self
    
    def transform(self, X_features, y_target=None):
        '''
        transform the training or test data based on info learned in fit step
        '''
        
        X_features_new = X_features.drop(self.cols_to_filter, axis=1)
        return X_features_new

# %%
p = Preprocessor(cols_to_filter=['Competitor Type'])
p.transform(train_X).head()
# Out:
#                           Supplies Subgroup          Supplies Group  \
# Opportunity Number
# 6748356             Batteries & Accessories         Car Accessories
# 9608239                Exterior Accessories         Car Accessories
# 8139132                   Garage & Car Care         Car Accessories
# 8423006                    Motorcycle Parts  Performance & Non-auto
# 8104406                    Motorcycle Parts  Performance & Non-auto
#
#                        Region Route To Market  Elapsed Days In Sales Stage  \
# Opportunity Number
# 6748356             Northwest    Fields Sales                           91
# 9608239             Northeast        Reseller                           12
# 8139132               Pacific        Reseller                           35
# 8423006             Northwest        Reseller                            7
# 8104406               Midwest        Reseller                           26
#
#                     Sales Stage Change Count  \
# Opportunity Number
# 6748356                                    2
# 9608239                                    2
# 8139132                                    3
# 8423006                                    7
# 8104406                                    2
#
#                     Total Days Identified Through Closing  \
# Opportunity Number
# 6748356                                                 3
# 9608239                                                 5
# 8139132                                                 7
# 8423006                                                20
# 8104406                                                17
#
#                     Total Days Identified Through Qualified  \
# Opportunity Number
# 6748356                                                   3
# 9608239                                                   5
# 8139132                                                   7
# 8423006                                                  20
# 8104406                                                  17
#
#                     Opportunity Amount USD  Client Size By Revenue  \
# Opportunity Number
# 6748356                              20000                       4
# 9608239                               8000                       1
# 8139132                               9300                       1
# 8423006                              26315                       1
# 8104406                               9202                       1
#
#                     Client Size By Employee Count  \
# Opportunity Number
# 6748356                                         4
# 9608239                                         1
# 8139132                                         1
# 8423006                                         1
# 8104406                                         1
#
#                     Revenue From Client Past Two Years  \
# Opportunity Number
# 6748356                                              0
# 9608239                                              0
# 8139132                                              0
# 8423006                                              0
# 8104406                                              0
#
#                     Ratio Days Identified To Total Days  \
# Opportunity Number
# 6748356                                             1.0
# 9608239                                             0.0
# 8139132                                             0.0
# 8423006                                             0.0
# 8104406                                             0.0
#
#                     Ratio Days Validated To Total Days  \
# Opportunity Number
# 6748356                                       0.000000
# 9608239                                       1.000000
# 8139132                                       1.000000
# 8423006                                       0.172589
# 8104406                                       1.000000
#
#                     Ratio Days Qualified To Total Days  Deal Size Category
# Opportunity Number
# 6748356                                       0.000000                   2
# 9608239                                       0.000000                   1
# 8139132                                       0.000000                   1
# 8423006                                       0.827411                   3
# 8104406                                       0.000000                   1

# %% [markdown]
# ## Encoding Categorical/Discrete Features

# %%
class Preprocessor: 
    
    def __init__(self, cols_to_filter=None):
        self.cols_to_filter = cols_to_filter
        self.was_fit = False
        
    def fit(self, X_features, y_target=None):
        '''
        Learn information from training get to transform test set
        '''
        self.was_fit = True
        
        # Filter columns
        X_features_new = X_features.drop(self.cols_to_filter, axis=1)
        
        # Encode categorical variables
        self.categorical_features = X_features_new.dtypes[X_features_new.dtypes == 'object'].index
        
        dummies = pd.get_dummies(X_features_new, columns=self.categorical_features)
        self.col_names = dummies.columns
        del dummies
        
        return self
    
    def transform(self, X_features, y_target=None):
        '''
        transform the training or test data based on info learned in fit step
        '''
        if not self.was_fit:
            raise Error("Need to fit preprocessor first")
            
        # Filter columns
        X_features_new = X_features.drop(self.cols_to_filter, axis=1)
        
        # Encode categorical variables
        X_features_new = pd.get_dummies(X_features_new, columns=self.categorical_features)
        new_cols = set(self.col_names) - set(X_features_new.columns)
        
        for x in new_cols:
            X_features_new[x] = 0
        
        # Fill Null Values
        X_features_new = X_features_new.fillna(-1)   
        
        return X_features_new
    
    def fit_transform(self, X_features, y_target=None):
        '''
        fit and transform for sklearn pipeline
        '''
        
        return self.fit(X_features).transform(X_features)

# %%
p = Preprocessor(cols_to_filter=['Competitor Type'])
p.fit(train_X)
# Out:
# <__main__.Preprocessor instance at 0x118e5b830>

# %%
train_X_transformed = p.transform(train_X)

# %%
train_X_transformed.head()
# Out:
#                     Elapsed Days In Sales Stage  Sales Stage Change Count  \
# Opportunity Number
# 6748356                                      91                         2
# 9608239                                      12                         2
# 8139132                                      35                         3
# 8423006                                       7                         7
# 8104406                                      26                         2
#
#                     Total Days Identified Through Closing  \
# Opportunity Number
# 6748356                                                 3
# 9608239                                                 5
# 8139132                                                 7
# 8423006                                                20
# 8104406                                                17
#
#                     Total Days Identified Through Qualified  \
# Opportunity Number
# 6748356                                                   3
# 9608239                                                   5
# 8139132                                                   7
# 8423006                                                  20
# 8104406                                                  17
#
#                     Opportunity Amount USD  Client Size By Revenue  \
# Opportunity Number
# 6748356                              20000                       4
# 9608239                               8000                       1
# 8139132                               9300                       1
# 8423006                              26315                       1
# 8104406                               9202                       1
#
#                     Client Size By Employee Count  \
# Opportunity Number
# 6748356                                         4
# 9608239                                         1
# 8139132                                         1
# 8423006                                         1
# 8104406                                         1
#
#                     Revenue From Client Past Two Years  \
# Opportunity Number
# 6748356                                              0
# 9608239                                              0
# 8139132                                              0
# 8423006                                              0
# 8104406                                              0
#
#                     Ratio Days Identified To Total Days  \
# Opportunity Number
# 6748356                                             1.0
# 9608239                                             0.0
# 8139132                                             0.0
# 8423006                                             0.0
# 8104406                                             0.0
#
#                     Ratio Days Validated To Total Days  ...  Region_Northeast  \
# Opportunity Number                                      ...
# 6748356                                       0.000000  ...                 0
# 9608239                                       1.000000  ...                 1
# 8139132                                       1.000000  ...                 0
# 8423006                                       0.172589  ...                 0
# 8104406                                       1.000000  ...                 0
#
#                     Region_Northwest  Region_Pacific  Region_Southeast  \
# Opportunity Number
# 6748356                            1               0                 0
# 9608239                            0               0                 0
# 8139132                            0               1                 0
# 8423006                            1               0                 0
# 8104406                            0               0                 0
#
#                     Region_Southwest  Route To Market_Fields Sales  \
# Opportunity Number
# 6748356                            0                             1
# 9608239                            0                             0
# 8139132                            0                             0
# 8423006                            0                             0
# 8104406                            0                             0
#
#                     Route To Market_Other  Route To Market_Reseller  \
# Opportunity Number
# 6748356                                 0                         0
# 9608239                                 0                         1
# 8139132                                 0                         1
# 8423006                                 0                         1
# 8104406                                 0                         1
#
#                     Route To Market_Telecoverage  Route To Market_Telesales
# Opportunity Number
# 6748356                                        0                          0
# 9608239                                        0                          0
# 8139132                                        0                          0
# 8423006                                        0                          0
# 8104406                                        0                          0
#
# [5 rows x 39 columns]

# %%
assert all(train_X_transformed.isna().sum() == 0)
