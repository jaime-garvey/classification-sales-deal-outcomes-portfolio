# %% [markdown]
# Getting Started | Data Prep | Data Exploration | Preprocessing | Model Tuning | Final Model

# %%
# Make better use of Jupyter Notebook cell width
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
#import libraries 

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

#Class Imbalances
from imblearn.over_sampling import SMOTE, ADASYN

#Feature Selection
from sklearn.feature_selection import RFE

# modelling imports logistic regression
import statsmodels.api as sm

from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import precision_score, recall_score, accuracy_score, roc_auc_score, roc_curve, confusion_matrix, classification_report
from sklearn.preprocessing import MinMaxScaler
from sklearn.tree import DecisionTreeClassifier

#Naive Bayes
from sklearn.naive_bayes import BernoulliNB
from sklearn.metrics import accuracy_score

#Linear SVC
from sklearn.svm import LinearSVC

#KNN
from sklearn.neighbors import KNeighborsClassifier

#Random Forest
from sklearn.ensemble import RandomForestClassifier
from rfpimp import *

#Gradient Boosting
from sklearn.ensemble import GradientBoostingClassifier

#SVM
from sklearn.svm import SVC

#Visualization
import yellowbrick
from yellowbrick.classifier import ClassificationReport
from sklearn.tree import export_graphviz
import graphviz

import pickle
from io import StringIO

# %matplotlib inline
plt.style.use('fivethirtyeight')

# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# # Import Data

# %%
sales_full = pd.read_pickle('data_final.pickle')

# %%
# xtrain = pd.read_pickle('xtrain.pickle')
# ytrain = pd.read_pickle('ytrain.pickle')

# xtest = pd.read_pickle('xtest.pickle')
# ytest = pd.read_pickle('ytest.pickle')

# %%
sales_full.columns
# Out:
# Index(['oppid', 'daysinstage', 'stagechanges', 'daystoclose', 'daystoqual',
#        'oppvalue', 'sizebyrev', 'sizebyee', 'pastsale', 'ratioidtot',
#        'ratiovaltot', 'ratioqualtot', 'dealsizecat', 'var_Car Accessories',
#        'var_Car Electronics', 'var_Performance & Non-auto',
#        'var_Tires & Wheels', 'var_Mid-Atlantic', 'var_Midwest',
#        'var_Northeast', 'var_Northwest', 'var_Pacific', 'var_Southeast',
#        'var_Southwest', 'var_Fields Sales', 'var_Other', 'var_Reseller',
#        'var_Telecoverage', 'var_Telesales', 'var_Loss', 'var_Won'],
#       dtype='object')

# %%
sales_full.head(2)
# Out:
#      oppid  daysinstage  stagechanges  daystoclose  daystoqual  oppvalue  \
# 0  1641984           76            13          104         101         0
# 1  1658010           63             2          163         163         0
#
#    sizebyrev  sizebyee  pastsale  ratioidtot  ...  var_Pacific  var_Southeast  \
# 0          5         5         0     0.69636  ...            0              0
# 1          3         5         0     0.00000  ...            1              0
#
#    var_Southwest  var_Fields Sales  var_Other  var_Reseller  var_Telecoverage  \
# 0              0                 1          0             0                 0
# 1              0                 0          0             1                 0
#
#    var_Telesales  var_Loss  var_Won
# 0              0         0        1
# 1              0         1        0
#
# [2 rows x 31 columns]

# %%
# drop base case for dummies
sales_act = sales_full.drop(['var_Car Electronics', 'var_Mid-Atlantic', 'var_Telecoverage','var_Loss'], axis=1)

# %%
sales_act = sales_full

# %%
#11% of the data is returning customers
# create df to isolate new business
new_biz = sales_act[sales_act['pastsale'] == 0]

# %%
new_biz.head(2)

#[False False  True False  True False False  True  True  True  True  True
 # True  True  True  True  True  True  True  True False  True  True  True
 # True  True]
# Out:
#      oppid  daysinstage  stagechanges  daystoclose  daystoqual  oppvalue  \
# 0  1641984           76            13          104         101         0
# 1  1658010           63             2          163         163         0
#
#    sizebyrev  sizebyee  pastsale  ratioidtot  ...  var_Pacific  var_Southeast  \
# 0          5         5         0     0.69636  ...            0              0
# 1          3         5         0     0.00000  ...            1              0
#
#    var_Southwest  var_Fields Sales  var_Other  var_Reseller  var_Telecoverage  \
# 0              0                 1          0             0                 0
# 1              0                 0          0             1                 0
#
#    var_Telesales  var_Loss  var_Won
# 0              0         0        1
# 1              0         1        0
#
# [2 rows x 31 columns]

# %%
#pickle dataframes

with open('new_biz.pickle', 'wb') as to_write:
    pickle.dump(new_biz, to_write)

# %% [markdown]
# # Balancing Classes (Start)

# %%
new_biz = pd.read_pickle('new_biz.pickle')

# %%
new_biz.head(3)
# Out:
#      oppid  daysinstage  stagechanges  daystoclose  daystoqual  oppvalue  \
# 0  1641984           76            13          104         101         0
# 1  1658010           63             2          163         163         0
# 2  1674737           24             7           82          82      7750
#
#    sizebyrev  sizebyee  pastsale  ratioidtot  ...  var_Pacific  var_Southeast  \
# 0          5         5         0     0.69636  ...            0              0
# 1          3         5         0     0.00000  ...            1              0
# 2          1         1         0     1.00000  ...            1              0
#
#    var_Southwest  var_Fields Sales  var_Other  var_Reseller  var_Telecoverage  \
# 0              0                 1          0             0                 0
# 1              0                 0          0             1                 0
# 2              0                 0          0             1                 0
#
#    var_Telesales  var_Loss  var_Won
# ...

# %%
target_count =  new_biz.var_Won.value_counts(normalize=True)

# print class balance
print(f'Class 0: {target_count[0]}')
print(f'Class 1: {target_count[1]}')
print(f'Proportion: {round(target_count[0] / target_count[1], 2)} : 1')
print(f'Percentage of Majority Class (Loss): {round(target_count[0] / sum(target_count), 4)*100}')
# Out:
# Class 0: 0.8267685816668593
# Class 1: 0.17323141833314068
# Proportion: 4.77 : 1
# Percentage of Majority Class (Loss): 82.67999999999999

# %%
target_count.plot(kind='bar', title='Class Count', rot=0);

# %% [markdown]
# # Scaling Data

# %% [markdown]
# ## ADASYN

# %%
new_biz_vars=new_biz.columns.values.tolist()
y_ADA=new_biz['var_Won']
columns = [i for i in new_biz_vars if i not in y]

X_ADA=new_biz[columns]

# %%
ad = ADASYN(random_state=0)

Xa_train, Xa_test, ya_train, ya_test = train_test_split(X_ADA, y_ADA, test_size=0.3, random_state=0)

columns = Xa_train.columns

ad_data_Xa,ad_data_ya=ad.fit_sample(Xa_train, ya_train)

ad_data_Xa = pd.DataFrame(data=ad_data_Xa,columns=columns )
ad_data_ya= pd.DataFrame(data=ad_data_ya,columns=['var_Won'])

# we can Check the numbers of our data
print("length of oversampled data is ",len(ad_data_Xa))
print("Number of Lost opportunities in oversampled data",len(ad_data_ya[ad_data_ya['var_Won']==0]))
print("Number of Won opportunities",len(ad_data_ya[ad_data_ya['var_Won']==1]))
print("Proportion of Lost opportunities data in oversampled data is ",len(ad_data_ya[ad_data_ya['var_Won']==0])/len(ad_data_Xa))
print("Proportion of Won opportunities in oversampled data is ",len(ad_data_ya[ad_data_ya['var_Won']==1])/len(ad_data_Xa))
# Out:
# length of oversampled data is  79591
# Number of Lost opportunities in oversampled data 40021
# Number of Won opportunities 39570
# Proportion of Lost opportunities data in oversampled data is  0.5028332349134953
# Proportion of Won opportunities in oversampled data is  0.49716676508650476

# %%
cols2 = ['daystoqual','daysinstage','ratioqualtot', 'ratioidtot','ratiovaltot','stagechanges', 'dealsizecat','sizebyee',
        'var_Car Accessories','var_Car Electronics', 'var_Tires & Wheels', 'var_Fields Sales', 'var_Other',
       'var_Telecoverage', 'var_Telesales']

X2_ADA= X_ADA[cols2]
y2_ADA=y_ADA #['var_Won']

# %%
Xa_train, Xa_test, ya_train,ya_test = train_test_split(X2_ADA, y2_ADA, test_size=0.3, random_state=0)

# %% [markdown]
# ## SMOTE

# %%
new_biz_vars=new_biz.columns.values.tolist()
y=new_biz['var_Won']
columns = [i for i in new_biz_vars if i not in y]

X=new_biz[columns]

# %%
os = SMOTE(random_state=0)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

columns = X_train.columns

os_data_X,os_data_y=os.fit_sample(X_train, y_train)

os_data_X = pd.DataFrame(data=os_data_X,columns=columns )
os_data_y= pd.DataFrame(data=os_data_y,columns=['var_Won'])

# we can Check the numbers of our data
print("length of oversampled data is ",len(os_data_X))
print("Number of Lost opportunities in oversampled data",len(os_data_y[os_data_y['var_Won']==0]))
print("Number of Won opportunities",len(os_data_y[os_data_y['var_Won']==1]))
print("Proportion of Lost opportunities data in oversampled data is ",len(os_data_y[os_data_y['var_Won']==0])/len(os_data_X))
print("Proportion of Won opportunities in oversampled data is ",len(os_data_y[os_data_y['var_Won']==1])/len(os_data_X))
# Out:
# length of oversampled data is  80042
# Number of Lost opportunities in oversampled data 40021
# Number of Won opportunities 40021
# Proportion of Lost opportunities data in oversampled data is  0.5
# Proportion of Won opportunities in oversampled data is  0.5

# %% [markdown]
# # Feature Selection

# %%
new_biz_vars=new_biz.columns.values.tolist()
y=os_data_y
X=os_data_X


logreg = LogisticRegression()

rfe = RFE(logreg, 20)
rfe = rfe.fit(os_data_X, os_data_y.values.ravel())

print(rfe.support_)
print(rfe.ranking_)
# Out:
# /Users/Jaime/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/Jaime/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/Jaime/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/Jaime/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %% [markdown]
# **Removing**: oppid, days in stage, daystoclose, oppvalue, sizebyrev, Northwest
#
# Additional: 'var_Car Electronics', 'var_Other'

# %%
os_data_X.columns
# Out:
# Index(['oppid', 'daysinstage', 'stagechanges', 'daystoclose', 'daystoqual',
#        'oppvalue', 'sizebyrev', 'sizebyee', 'pastsale', 'ratioidtot',
#        'ratiovaltot', 'ratioqualtot', 'dealsizecat', 'var_Car Accessories',
#        'var_Car Electronics', 'var_Performance & Non-auto',
#        'var_Tires & Wheels', 'var_Mid-Atlantic', 'var_Midwest',
#        'var_Northeast', 'var_Northwest', 'var_Pacific', 'var_Southeast',
#        'var_Southwest', 'var_Fields Sales', 'var_Other', 'var_Reseller',
#        'var_Telecoverage', 'var_Telesales', 'var_Loss', 'var_Won'],
#       dtype='object')

# %%
# cols = ['stagechanges','daystoqual', 'sizebyee', 'pastsale', 'ratioidtot',
#        'ratiovaltot', 'ratioqualtot', 'dealsizecat', 'var_Car Accessories', 'var_Performance & Non-auto',
#        'var_Car Electronics', 'var_Tires & Wheels', 'var_Mid-Atlantic', 'var_Midwest',
#        'var_Northeast', 'var_Pacific', 'var_Southeast',
#        'var_Southwest', 'var_Fields Sales', 'var_Reseller',
#        'var_Telecoverage', 'var_Telesales']

#dropping - 'oppvalue', 'daystoclose', 'var_Performance & Non-auto','var_reseller'

cols = ['daysinstage', 'stagechanges','daystoqual','sizebyee', 'ratioidtot',
       'ratiovaltot', 'ratioqualtot', 'dealsizecat', 'var_Car Accessories',
       'var_Car Electronics', 'var_Tires & Wheels', 'var_Mid-Atlantic', 'var_Midwest',
       'var_Northeast', 'var_Northwest', 'var_Pacific', 'var_Southeast',
       'var_Southwest', 'var_Fields Sales', 'var_Other',
       'var_Telecoverage', 'var_Telesales']



X1=os_data_X[cols]
y1=os_data_y #['var_Won']

# %% [markdown]
# # Scaling & Spliting Data

# %%
cols2 = ['daystoqual','daysinstage','ratioqualtot', 'ratioidtot','ratiovaltot','stagechanges', 'dealsizecat','sizebyee',
        'var_Car Accessories','var_Car Electronics', 'var_Tires & Wheels', 'var_Fields Sales', 'var_Other',
       'var_Telecoverage', 'var_Telesales']

X2= X1[cols2]
y2=y1 #['var_Won']

# %%
X2.columns
# Out:
# Index(['daystoqual', 'daysinstage', 'ratioqualtot', 'ratioidtot',
#        'ratiovaltot', 'stagechanges', 'dealsizecat', 'sizebyee',
#        'var_Car Accessories', 'var_Car Electronics', 'var_Tires & Wheels',
#        'var_Fields Sales', 'var_Other', 'var_Telecoverage', 'var_Telesales'],
#       dtype='object')

# %%
X2_train, X2_test, y2_train,y2_test = train_test_split(X2, y2, test_size=0.3, random_state=0)

# %% [markdown]
# ## Pair Plot

# %%
pairplot_output = sns.pairplot(, hue='oppoutcome');

# %%
sns.stripplot(x='daystoqual',y='oppoutcome', jitter=True,data=train_df,alpha=0.6);

# %%
pairplot_output.savefig("output.png")

# %%
#pickle pairplot
with open('pairplot_output.pkl','wb') as fid:
    pickle.dump(pairplot_output, fid)

# %% [markdown]
# # Logistic Regression

# %%
X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.3, random_state=0)

# %%
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
# Out:
# /Users/Jaime/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/Jaime/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
y_pred = logreg.predict(X_test)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.79

# %%
recall_score(y_test, y_pred)
# Out:
# 0.8191735537190082

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[9138, 2775],
#        [2188, 9912]])

# %% [markdown]
# **Results**
# ```
# [ 9896,  2718],
# [ 2248, 10531]
# ```
# precision = tp / (tp + fp)
# recall = ratio tp / (tp + fn)
# f-beta score = weighted harmonic mean of the precision and recall (perfect = 1)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.77      0.79     11913
#            1       0.78      0.82      0.80     12100
#
#    micro avg       0.79      0.79      0.79     24013
#    macro avg       0.79      0.79      0.79     24013
# weighted avg       0.79      0.79      0.79     24013

# %%
logreg2 = LogisticRegression()
logreg2.fit(X_train_std, y2_train)
# Out:
# /Users/Jaime/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/Jaime/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
y2_pred = logreg2.predict(X_test_std)

# %%
recall_score(y2_test, y2_pred)
# Out:
# 0.8165289256198347

# %% [markdown]
# ## Reciever Operating Characteristic (ROC) Curve

# %%
logit_roc_auc = roc_auc_score(y_test, logreg.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, logreg.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()

# %% [markdown]
# # Naive Bayes

# %%
bnb = BernoulliNB()

#train the data using training data and predict using test data
prediction = bnb.fit(X=X_train, y=y_train).predict(X_test)
#prediction.tolist()

# %%
accuracy_score(y_test, prediction, normalize = True)
# Out:
# 0.764585849331612

# %%
recall_score(y_test, prediction)
# Out:
# 0.7342148760330579

# %%
print(classification_report(y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.80      0.77     11913
#            1       0.78      0.73      0.76     12100
#
#    micro avg       0.76      0.76      0.76     24013
#    macro avg       0.77      0.76      0.76     24013
# weighted avg       0.77      0.76      0.76     24013

# %%
mat = confusion_matrix(y_test, prediction)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False,
            xticklabels= y_train.unique(), yticklabels=y_train.unique())
plt.xlabel('true label')
plt.ylabel('predicted label');

# %%
bnb_roc_auc = roc_auc_score(y_test, bnb.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, bnb.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Naive Bayes (area = %0.2f)' % bnb_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()

# %%
svc_model = LinearSVC(random_state =0)
prediction_svc = svc_model.fit(X_train,y_train).predict(X_test)
# Out:
# /Users/Jaime/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
accuracy_score(ytest, prediction, normalize = True)

# %% [markdown]
# # K Nearest Neighbors

# %%
n = KNeighborsClassifier(n_neighbors=5)
prediction_n = n.fit(X_train,y_train).predict(X_test)
#print(prediction.tolist())

# %%
confusion_matrix(y_test, prediction_n)
# Out:
# array([[ 8839,  3074],
#        [ 1436, 10664]])

# %%
print(classification_report(y_test, prediction_n))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.74      0.80     11913
#            1       0.78      0.88      0.83     12100
#
#    micro avg       0.81      0.81      0.81     24013
#    macro avg       0.82      0.81      0.81     24013
# weighted avg       0.82      0.81      0.81     24013

# %%
recall_score(y_test,prediction_n)
# Out:
# 0.8813223140495868

# %% [markdown]
# ### Testing k values

# %%
# # try K=1 through K=25 and record testing recall
# k_range = range(1, 26)

# # We can create Python dictionary using [] or dict()
# scores = []

# # We use a loop through the range 1 to 26
# # We append the scores in the dictionary
# for k in k_range:
#     knn = KNeighborsClassifier(n_neighbors=k)
#     knn.fit(X_train, y_train)
#     y_pred = knn.predict(X_test)
#     scores.append(metrics.recall_score(y_test, y_pred))

# print(scores)

# %%
# k_range = range(1,26)
# weight = ['uniform','distance']
# param_grid = dict(n_neighbors=k_range, weights=weight)

# %%
# neigh = KNeighborsClassifier()
# grid = GridSearchCV(neigh,param_grid,cv=10,scoring='accuracy')
# grid.fit(X_train, y_train)

# print(grid.best_score_)
# print(grid.best_params_)

# %% [markdown]
# # Decision Tree

# %%
dt_model = DecisionTreeClassifier()
dtt = dt_model.fit(X_train, y_train)
prediction_dt = dtt.predict(X_test)
recall_score(y_test, prediction_dt)
#accuracy_score(y_test, prediction_dt)
# Out:
# 0.8980165289256198

# %%
confusion_matrix(y_test, prediction_dt)
# Out:
# array([[10650,  1263],
#        [ 1223, 10877]])

# %%
dt2_model = DecisionTreeClassifier(max_depth=5)
dt2_model.fit(X2_train, y2_train)
#prediction_dt2 = dtt.predict(X2_test)
#recall_score(y2_test, prediction_dt2)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
prediction_dt2 = dt2_model.fit(X2_train, y2_train).predict(X2_test)
recall_score(y2_test, prediction_dt2)
# Out:
# 0.8192561983471074

# %%
confusion_matrix(y2_test, prediction_dt2)
# Out:
# array([[9788, 2125],
#        [2187, 9913]])

# %%
I_dt = importances(dt, X_train, y_train, n_samples=-1)

# %%
I_dt
# Out:
#                      Importance
# Feature
# stagechanges           0.192168
# ratioqualtot           0.178872
# daystoqual             0.159078
# var_Fields Sales       0.138446
# daysinstage            0.101929
# ratiovaltot            0.089043
# dealsizecat            0.084778
# ratioidtot             0.046458
# var_Midwest            0.039319
# var_Car Accessories    0.024755
# var_Pacific            0.021828
# sizebyee               0.019365
# var_Northeast          0.014939
# var_Southwest          0.012654
# var_Northwest          0.011423
# var_Mid-Atlantic       0.011119
# var_Southeast          0.010263
# var_Telesales          0.004605
# var_Other              0.004569
# var_Tires & Wheels     0.000678
# var_Car Electronics    0.000678
# var_Telecoverage       0.000553

# %%
#Pickle model

with open("dt2_model.pkl", "wb") as f:
    pickle.dump(dt_model, f)

# %%
plot_importances(I_dt)

# %% [markdown]
# ## Visualizing the Tree

# %%
dot_data = export_graphviz(dt2_model, out_file=None, 
                rounded = True, proportion = False, 
                precision = 2, filled = True)

# %%
graph = graphviz.Source(dot_data)

# %%
graph.render("tree")
# Out:
# 'tree.pdf'

# %% [markdown]
# # Random Forest

# %%
rf = RandomForestClassifier(n_estimators=10, max_features='sqrt', bootstrap = True, random_state=0)
rff = rf.fit(X_train, y_train)
print("Accuracy on training set: {:.3f}".format(rff.score(X_train, y_train)))
print("Accuracy on test set: {:.3f}".format(rff.score(X_test, y_test)))
# Out:
# Accuracy on training set: 1.000
# Accuracy on test set: 1.000

# %%
prediction_rf = rff.predict(X_test)
recall_score(y_test, prediction_rf)
# Out:
# 0.8941322314049587

# %%
confusion_matrix(y_test, prediction_rf)
# Out:
# array([[11250,   663],
#        [ 1281, 10819]])

# %%
mat = confusion_matrix(y_test, prediction_rf)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False,
            xticklabels= y_train.unique(), yticklabels=y_train.unique())
plt.xlabel('true label')
plt.ylabel('predicted label')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-136-56521ca4e4ab> in <module>
#       1 mat = confusion_matrix(y_test, prediction_rf)
#       2 sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False,
# ----> 3             xticklabels= y_train.unique(), yticklabels=y_train.unique())
#       4 plt.xlabel('true label')
#       5 plt.ylabel('predicted label')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
rf_roc_auc = roc_auc_score(y_test, rf.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, rf.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Random Forest (area = %0.2f)' % rf_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()

# %%
rf2 = RandomForestClassifier(n_estimators=10, max_features='sqrt', bootstrap = True, random_state=0)

rff2 = rf2.fit(X2_train, y2_train)
print("Accuracy on training set: {:.3f}".format(rff2.score(X2_train, y2_train)))
print("Accuracy on test set: {:.3f}".format(rff2.score(X2_test, y2_test)))
# Out:
# /Users/Jaime/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# Accuracy on training set: 0.989
# Accuracy on test set: 0.914

# %%
prediction_rf2 = rff2.predict(X2_test)
recall_score(y2_test, prediction_rf2)
# Out:
# 0.8967768595041322

# %%
I_rf2 = importances(rf2, X2_train, y2_train, n_samples=-1)

# %%
I_rf2
# Out:
#                      Importance
# Feature
# ratioqualtot           0.129076
# daystoqual             0.122240
# stagechanges           0.118367
# ratiovaltot            0.107516
# var_Fields Sales       0.087455
# daysinstage            0.072784
# dealsizecat            0.072391
# var_Car Accessories    0.065359
# ratioidtot             0.056239
# sizebyee               0.024862
# var_Telesales          0.004926
# var_Other              0.004890
# var_Telecoverage       0.000750
# var_Tires & Wheels     0.000678
# var_Car Electronics    0.000357

# %%
plot_importances(I_rf2)

# %%
y2_train_arr = np.array(y2_train['var_Won'])

# %%
y2_test_arr = np.array(y2_test['var_Won'])

# %%
y2_train_rav = np.ravel(y2_train['var_Won'])

# %%
y2_test_rav = np.ravel(y2_test['var_Won'])

# %%
y2_train_rav
# Out:
# array([1, 1, 0, ..., 0, 0, 1], dtype=uint8)

# %% [markdown]
# ### Tuning

# %%
rfc=RandomForestClassifier(random_state=0)

# %%
from sklearn.metrics import roc_curve, auc
from matplotlib.legend_handler import HandlerLine2D

# %%
y_test.shape
# Out:
# (20763,)

# %% [markdown]
# Note: Default Parameters are more performant

# %% [markdown]
# ### Feature Importance

# %%
I = importances(rf, X1, y1, n_samples=-1)

# %%
plot_importances(I)

# %%
importances_df = pd.DataFrame(I)

# %%
importances_df
# Out:
#                      Importance
# Feature
# daystoqual             0.086430
# var_Fields Sales       0.079421
# ratioqualtot           0.068676
# ratiovaltot            0.062267
# stagechanges           0.061068
# dealsizecat            0.047488
# daysinstage            0.042065
# var_Midwest            0.034944
# var_Car Accessories    0.029360
# ratioidtot             0.026723
# var_Pacific            0.016104
# sizebyee               0.010694
# var_Southeast          0.007059
# var_Southwest          0.006397
# var_Northwest          0.006097
# var_Northeast          0.005160
# var_Mid-Atlantic       0.004598
# var_Telesales          0.002724
# var_Other              0.002274
# var_Telecoverage       0.000387
# var_Tires & Wheels     0.000262
# var_Car Electronics    0.000212

# %%
#pickle dataframes

with open('importances_df.pickle', 'wb') as to_write:
    pickle.dump(importances_df, to_write)

# %%
IC = dropcol_importances(rf, X_train, y_train, X_valid=X_test, y_valid=y_test)

# %%
plot_importances(IC)

# %%
from eli5.sklearn import PermutationImportance
perm = PermutationImportance(rf).fit(X_test, y_test)

# %%
from rfpimp import plot_corr_heatmap
viz = plot_corr_heatmap(X_train, figsize=(15,12))
viz.view()

# %% [markdown]
# # Boosting

# %%
gb = GradientBoostingClassifier(random_state=0)
gb.fit(X_train, y_train)
print("Accuracy on training set: {:.3f}".format(gb.score(X_train, y_train)))
print("Accuracy on test set: {:.3f}".format(gb.score(X_test, y_test)))
# Out:
# Accuracy on training set: 0.899
# Accuracy on test set: 0.899

# %%
prediction_gb = gb.fit(X_train, y_train).predict(X_test)
recall_score(y_test, prediction_gb)
# Out:
# 0.8790202676265748

# %%
gb1 = GradientBoostingClassifier(random_state=0, max_depth=1)
gb1.fit(X_train, y_train)
print("Accuracy on training set: {:.3f}".format(gb1.score(X_train, y_train)))
print("Accuracy on test set: {:.3f}".format(gb1.score(X_test, y_test)))
# Out:
# Accuracy on training set: 0.861
# Accuracy on test set: 0.863

# %%
prediction_gb1 = gb1.fit(X_train, y_train).predict(X_test)
recall_score(y_test, prediction_gb1)
# Out:
# 0.8499100086078722

# %%
gb2 = GradientBoostingClassifier(random_state=0, learning_rate=0.01)
gb2.fit(X_train, y_train)
print("Accuracy on training set: {:.3f}".format(gb2.score(X_train, y_train)))
print("Accuracy on test set: {:.3f}".format(gb2.score(X_test, y_test)))
# Out:
# Accuracy on training set: 0.849
# Accuracy on test set: 0.851

# %%
prediction_gb2 = gb2.fit(X_train, y_train).predict(X_test)
recall_score(y_test, prediction_gb2)
# Out:
# 0.852648877063933

# %%
svc = SVC()
svc.fit(X_train, y_train)
print("Accuracy on training set: {:.2f}".format(svc.score(X_train, y_train)))
print("Accuracy on test set: {:.2f}".format(svc.score(X_test, y_test)))
# Out:
# /Users/Jaime/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-144-3336bd350362> in <module>
#       1 svc = SVC()
#       2 svc.fit(X_train, y_train)
# ----> 3 print("Accuracy on training set: {:.2f}".format(svc.score(X_train, y_train)))
#       4 print("Accuracy on test set: {:.2f}".format(svc.score(X_test, y_test)))
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     286         """
#     287         from .metrics import accuracy_score
# ...

# %%
svc = SVC()
prediction_svc = svc.fit(X_train, y_train).predict(X_test)
recall_score(y_test, prediction_svc)

# %% [markdown]
# # Comparing Models

# %%
visualizer = ClassificationReport(logreg, classes=['Won','Loss'])
visualizer.fit(X_train, y_train)
visualizer.score(X_test, y_test)
g = visualizer.poof()
# Out:
# /Users/Jaime/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
visualizer = ClassificationReport(gnb, classes=['Won','Loss'])
visualizer.fit(X_train, y_train)
visualizer.score(X_test, y_test)
g = visualizer.poof()

# %%
visualizer = ClassificationReport(n, classes=['Won','Loss'])
visualizer.fit(X_train, y_train)
visualizer.score(X_test, y_test)
g = visualizer.poof()

# %%
visualizer = ClassificationReport(rf, classes=['Won','Loss'])
visualizer.fit(X_train, y_train)
visualizer.score(X_test, y_test)
g = visualizer.poof()

# %%
visualizer = ClassificationReport(gb, classes=['Won','Loss'])
visualizer.fit(X_train, y_train)
visualizer.score(X_test, y_test)
g = visualizer.poof()
